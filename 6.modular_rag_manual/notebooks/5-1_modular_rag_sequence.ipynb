# %% [markdown]
# # 5-1. Modular RAG 순차 파이프라인
#
# ## 학습 목표
#
# - LangGraph Basic RAG를 Modular RAG로 확장한다.
# - 질문 분류, 검색, 근거 정리, 답변 생성, 검증을 각각 노드로 분리한다.
# - 아직 `src` 파일을 사용하지 않고 노트북 안에서 전체 구조를 구현한다.

# %% [markdown]
# ## 공통 전제
#
# - 실습 데이터: `../data/공직자_민원응대_핵심_매뉴얼.pdf`
# - 기본 모델: `gpt-4o-mini`
# - 기본 임베딩 모델: `text-embedding-3-small`
# - 벡터DB: Qdrant 로컬 인메모리 모드
#
# > 이 노트북은 `src` 파일을 import하지 않고, 노트북 안의 코드만으로 실행되도록 구성한다.

# %%
from typing_extensions import TypedDict, NotRequired

from dotenv import load_dotenv

load_dotenv(override=True, dotenv_path="../../.env")
# Out:
# True

# %% [markdown]
# ## 1. 벡터스토어 객체 생성

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore

QDRANT_URL = "http://localhost:6333"
COLLECTION_NAME = "civil_complaint_manual_medium"

EMBEDDING_MODEL = "text-embedding-3-small"

embeddings = OpenAIEmbeddings(model=EMBEDDING_MODEL)

vector_store = QdrantVectorStore.from_existing_collection(
    embedding=embeddings,
    collection_name=COLLECTION_NAME,
    url=QDRANT_URL,
)

# %% [markdown]
# ## 2. 질문 유형 분류 함수
#
# 처음에는 LLM 분류가 아니라 규칙 기반 분류로 단순하게 구현한다.

# %%
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langgraph.graph import StateGraph, START, END

def classify_question(question: str) -> dict:
    rules = [
        ("repeat_call", ["반복", "계속 전화", "같은 말", "동일"]),
        ("long_call", ["장시간", "오래", "권장시간", "20분", "15분"]),
        ("supervisor_request", ["상급자", "기관장", "부서장", "팀장"]),
        ("phone_abuse", ["전화", "욕설", "폭언", "협박", "성희롱"]),
        ("face_to_face_abuse", ["대면", "방문", "욕설", "폭언"]),
        ("violence", ["폭행", "때리", "물리"]),
        ("property_damage", ["파손", "부수", "집기", "물품"]),
        ("dangerous_object", ["위험물", "흉기", "칼", "인화물질", "불"]),
        ("online_abuse", ["온라인", "문서", "인터넷"]),
        ("recovery_protection", ["보호", "휴식", "휴가", "심리", "치료"]),
        ("legal_basis", ["법", "처벌", "형량", "고소", "고발"]),
    ]

    for case_type, keywords in rules:
        if any(keyword in question for keyword in keywords):
            return {
                "case_type": case_type,
                "rewritten_query": rewrite_query(question, case_type)
            }

    return {
        "case_type": "general",
        "rewritten_query": question
    }


def rewrite_query(question: str, case_type: str) -> str:
    expansions = {
        "repeat_call": "정당한 사유 없는 반복전화 동일민원 통화 종료 상담 종료",
        "long_call": "정당한 사유 없는 장시간 통화 권장시간 상담 종료",
        "supervisor_request": "상급자 기관장 통화 요구 실무자 대응 담당 팀장 대응",
        "phone_abuse": "전화응대 폭언 욕설 협박 성희롱 증거 확보 통화 종료",
        "face_to_face_abuse": "대면응대 폭언 욕설 협박 성희롱 녹화 녹음 상담 종료",
        "violence": "대면응대 폭행 비상대응팀 경찰 신고 피해공무원 분리",
        "property_damage": "집기 물품 파손 공용물건손상 경찰 신고 비상대응팀",
        "dangerous_object": "위험물 소지 흉기 인화물질 경찰 신고 119 신고 대피",
        "online_abuse": "온라인 문서민원 폭언 경고공문 부서장 보고",
        "recovery_protection": "민원담당자 회복 보호조치 휴식 휴가 심리상담 치료 지원",
        "legal_basis": "위법행위 유형별 적용 법률 형법 경범죄처벌법 공무집행방해",
    }

    return f"{question}\n검색 키워드: {expansions.get(case_type, '')}".strip()

# %% [markdown]
# ## 3. 프롬프트 구성

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# 근거 정리 프롬프트
evidence_prompt = ChatPromptTemplate.from_messages([
    ("system", '''
검색된 문단에서 질문 답변에 필요한 핵심 근거만 정리하세요.
문단에 없는 내용은 추가하지 마세요. 페이지를 포함하세요.
'''),
    ("human", '''
질문:
{question}

검색 문단:
{context}
''')
])

# 답변 생성 프롬프트
answer_prompt = ChatPromptTemplate.from_messages([
    ("system", '''
당신은 공직자 민원응대 매뉴얼 기반 업무지원 AI입니다.
제공된 근거를 바탕으로만 답변하세요. 
매뉴얼에 없는 내용은 추측하지 마세요.

답변 형식:
1. 핵심 대응
2. 단계별 조치
3. 사용할 수 있는 안내 표현
4. 담당자 보호조치
5. 주의사항
6. 문서 페이지
'''),
    ("human", '''
질문:
{question}

근거:
{evidence}
''')
])

# 답변 검증 프롬프트
validation_prompt = ChatPromptTemplate.from_messages([
    ("system", '''
당신은 RAG 답변 검토자입니다.
답변이 근거에 기반하는지 검토하세요.
결과는 '충분', '부분충분', '부족' 중 하나로 시작하세요.
'''),
    ("human", '''
질문:
{question}

검색 근거:
{context}

답변:
{answer}
''')
])

evidence_chain = evidence_prompt | llm | StrOutputParser()
answer_chain = answer_prompt | llm | StrOutputParser()
validation_chain = validation_prompt | llm | StrOutputParser()

# %% [markdown]
# ## 4. 유틸 함수

# %%
def format_docs(docs: list[Document]) -> str:
    formatted = []

    for i, doc in enumerate(docs, start=1):
        formatted.append(
            f"[근거 {i}] page={doc.metadata.get('page')}, chunk={doc.metadata.get('chunk_id')}\n"
            f"{doc.page_content}"
        )

    return "\n\n".join(formatted)

# %% [markdown]
# ## 5. State 정의

# %%
class ModularRAGState(TypedDict):
    question: str
    case_type: NotRequired[str]
    rewritten_query: NotRequired[str]
    documents: NotRequired[list[Document]]
    context: NotRequired[str]
    evidence: NotRequired[str]
    answer: NotRequired[str]
    validation: NotRequired[str]

# %% [markdown]
# ## 6. Node 정의

# %%
# ── 노드 1: 질문 분류 ─────────────────────────────────
def classify_question_node(state: ModularRAGState) -> dict:
    result = classify_question(state["question"])

    return {
        "case_type": result["case_type"],
        "rewritten_query": result["rewritten_query"]
    }

# ── 노드 2: 매뉴얼 검색 ──────────────────────────────
def retrieve_manual_node(state: ModularRAGState) -> dict:
    query = state.get("rewritten_query") or state["question"]
    docs = vector_store.similarity_search(query, k=4)
    context = format_docs(docs)

    return {
        "documents": docs,
        "context": context
    }

# ── 노드 3: 근거 정리 ─────────────────────────────────
def organize_evidence_node(state: ModularRAGState) -> dict:
    evidence = evidence_chain.invoke({
        "question": state["question"],
        "context": state["context"]
    })

    return {
        "evidence": evidence
    }

# ── 노드 4: 답변 생성 ─────────────────────────────────
def generate_answer_node(state: ModularRAGState) -> dict:
    answer = answer_chain.invoke({
        "question": state["question"],
        "evidence": state["evidence"]
    })

    return {
        "answer": answer
    }

# ── 노드 5: 답변 검증 ─────────────────────────────────
def validate_answer_node(state: ModularRAGState) -> dict:
    validation = validation_chain.invoke({
        "question": state["question"],
        "context": state["context"],
        "answer": state["answer"]
    })

    return {
        "validation": validation
    }

# %% [markdown]
# ## 7. Graph 구성

# %%
graph = StateGraph(ModularRAGState)

graph.add_node("classify_question", classify_question_node)
graph.add_node("retrieve_manual", retrieve_manual_node)
graph.add_node("organize_evidence", organize_evidence_node)
graph.add_node("generate_answer", generate_answer_node)
graph.add_node("validate_answer", validate_answer_node)

graph.add_edge(START, "classify_question")
graph.add_edge("classify_question", "retrieve_manual")
graph.add_edge("retrieve_manual", "organize_evidence")
graph.add_edge("organize_evidence", "generate_answer")
graph.add_edge("generate_answer", "validate_answer")
graph.add_edge("validate_answer", END)

app = graph.compile()

# %% [markdown]
# ### 그래프 시각화

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## 8. 실행

# %%
question = "대면 민원 중 폭행이 발생하면 어떻게 해야 하나요?"

result = app.invoke({
    "question": question
})

result
# print("[질문 유형]")
# print(result["case_type"])

# print("\n[검색 질의]")
# print(result["rewritten_query"])

# print("\n[근거 정리]")
# print(result["evidence"])

# print("\n[답변]")
# print(result["answer"])

# print("\n[검증]")
# print(result["validation"])
# Out:
# {'question': '대면 민원 중 폭행이 발생하면 어떻게 해야 하나요?',
#  'case_type': 'face_to_face_abuse',
#  'rewritten_query': '대면 민원 중 폭행이 발생하면 어떻게 해야 하나요?\n검색 키워드: 대면응대 폭언 욕설 협박 성희롱 녹화 녹음 상담 종료',
#  'documents': [Document(metadata={'source': '공직자_민원응대_핵심_매뉴얼_rag_page_chunks.md', 'page': 8, 'section': '특이민원 응대요령', 'topic': '상급자 통화 요구', 'document_type': 'preprocessed_markdown', 'chunk_type': 'page', 'chunk_id': 11, 'chunk_size': 700, 'chunk_overlap': 120, 'chunk_strategy': 'medium', 'embedding_model': 'text-embedding-3-small', 'collection_name': 'civil_complaint_manual_medium', '_id': '38b200a2-adff-4695-a3e6-45162a284156', '_collection_name': 'civil_complaint_manual_medium'}, page_content='3-1 폭언(욕설, 협박, 성희롱 등)\n3-2 폭행\n‣ ~~폭행 발생 징후가 보일 경우 즉시 주변에 도움 요청,~~\n~~담당자 현장에서 분리조치, 팀장 등 경고멘트 발언 및 개입~~\n녹화(음) 중이 아닐 경우 즉시 녹화(음) 실시\n선생님, 위협적인 행동과 말씀으로 더 이상 정상적인 상담이 어렵습니다.\n팀장님(주무관님) 도움 부탁드립니다.\n비상대응팀 업무분장에 따라 신속히 대응\n- ~~팀장~~ 민원인 진정 및 경고 → 퇴거 조치 → 안전요원(경찰)과 동행\n※ 진정되지 않고 폭행 발생이 예상되는 경우 즉시 경찰 신고\n‣ ~~상담곤란 안내 후 상담 종료, 주변 도움 요청~~\n녹화(음) 중이 아닐 경우 즉시 녹화(음) 실시\n선생님, 폭언을 하시면 정상적인 상담이 어렵습니다. 폭언을 중단해 주십시오.\n계속 폭언을 하시면 관련 법령에 따라 처벌받을 수 있습니다.\n팀장님(주무관님) 민원인이 폭언을 하셔서 더 이상 상담이 어려우니 도움\n부탁드립니다.\n‣ ~~비상대응팀 업무분장에 따라 신속히 행동~~\n비상대응팀 직원별 역할 수행\n- ~~팀장~~ 민원인 진정 및 경고 → (폭언 등 지속시) 퇴거 조치 → 안전요원(경찰)과 동행\n※ 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의'),
#   Document(metadata={'source': '공직자_민원응대_핵심_매뉴얼_rag_page_chunks.md', 'page': 10, 'section': '특이민원 응대요령', 'topic': '상급자 통화 요구', 'document_type': 'preprocessed_markdown', 'chunk_type': 'page', 'chunk_id': 17, 'chunk_size': 700, 'chunk_overlap': 120, 'chunk_strategy': 'medium', 'embedding_model': 'text-embedding-3-small', 'collection_name': 'civil_complaint_manual_medium', '_id': '9a73ee42-072a-430d-84bc-a1155b3bac70', '_collection_name': 'civil_complaint_manual_medium'}, page_content='4-1 폭언(욕설, 협박, 성희롱 등)\n핵심대응 전화·대면 폭언 등에 준하여 대응함으로써 민원인에게 경각심 부여\n4-2 정당한 사유없는 반복민원 ※ 민원처리법 제23조, 제34조\n핵심대응 반복민원 종결처리로 불필요한 행정력 낭비 방지\n‣ ~~처리 주무부서장 결재로 종결~~\n※ 2차 답변시 민원인의 이해를 높이는 방식으로 대응, 기존 답변 단순복사,\n동문서답 등 성의없는 답변 후 종결 처리로 국민불만 발생 유의\n[종결처리 통지] 최초 종결 처리시, 민원인에게 종결처리 사실을 통지\n하고 이후 제기된 반복민원은 처리결과 회신없이 종결\n[처리기준] 동일한 내용의 민원을 3회이상 반복 제출한 경우 2회이상\n그 결과를 통지하고 이후 접수 민원은 종결처리 가능\n‣ ~~기관별 민원조정위원회 심의~~\n종결 처리 후 다시 접수된 반복민원 중 처리주무부서장이 신중한\n처리가 필요하다고 판단, 기관별 민원조정위원회 심의로 종결\n‣ ~~해당 민원 내용을 부서장에게 보고~~\n담당자는 위법행위 관리대장 작성, 부서장 보고\n※ 필요시 특이민원 발생보고서 작성(상황에 따라 구두보고 후 작성)\n‣ ~~경고공문 통지~~\n민원 회신 시 법적조치 등을 취할 수 있다는 경고문구 포함 회신\n[ 경고문구(예시) ]\n◦ 귀하께서 2000.00.00. 에 제출하신 민원(제목:00) 내용 중 “×××”는 「00법」 제0조'),
#   Document(metadata={'source': '공직자_민원응대_핵심_매뉴얼_rag_page_chunks.md', 'page': 4, 'section': '민원응대 관련 기본원칙', 'topic': '상급자 통화 요구', 'document_type': 'preprocessed_markdown', 'chunk_type': 'page', 'chunk_id': 4, 'chunk_size': 700, 'chunk_overlap': 120, 'chunk_strategy': 'medium', 'embedding_model': 'text-embedding-3-small', 'collection_name': 'civil_complaint_manual_medium', '_id': '4109edaa-7dcc-48c1-bba6-d354231ed870', '_collection_name': 'civil_complaint_manual_medium'}, page_content='STEP\nSTEP\n- 정중한 억양 및 어투를 사용하며, 민원사항에 대한 공감·경청\n※무성의한 응대나 주관적·모호한 응대 주의\n- 민원인 문의사항을 집중하여 끝까지 듣고, 필요시 확인을 통해\n민원사항을 정확히 파악\nSTEP\n- 민원인의 눈높이에 맞춘 정확하고 이해하기 쉬운 설명 진행\nSTEP\nSTEP\n- 민원인이 제기한 불만 원인을 파악하고, 절차 안내, 민원 해결 방안\n또는 민원인에게 해결이 어려운 상황을 설명\n※ 명확한 근거규정을 제시하고 어려울 경우 충분한 준비 후 재응대\n- 민원인에게 민원문서의 보완 요구, 처리진행상황 및 처리결과를\n통보할 때에는 담당자의 소속·성명 및 연락처를 안내\nSTEP\nSTEP\n- 민원인의 방문목적을 확인하고 민원처리 또는 상담을 진행\n※ 상담 중 민원인과의 마찰 또는 갈등이 발생할 우려가 있는 경우에는 부서장 또는\n상급자가 적극 개입하여 민원인을 진정시키고 갈등을 해소할 수 있도록 노력\n- 민원인의 질문과 요구를 적극적으로 해결하기 위해 노력\n※ 자신의 업무 범위만 내세워 소극적으로 대처하지 않음\nSTEP\n- 처리에 시간이 걸리는 민원은 소요시간과 절차 안내\nII. 일반적인 민원 응대요령 | **11**'),
#   Document(metadata={'source': '공직자_민원응대_핵심_매뉴얼_rag_page_chunks.md', 'page': 8, 'section': '특이민원 응대요령', 'topic': '상급자 통화 요구', 'document_type': 'preprocessed_markdown', 'chunk_type': 'page', 'chunk_id': 12, 'chunk_size': 700, 'chunk_overlap': 120, 'chunk_strategy': 'medium', 'embedding_model': 'text-embedding-3-small', 'collection_name': 'civil_complaint_manual_medium', '_id': '5b3fe260-7166-4dd6-bad0-4bcc2106fd69', '_collection_name': 'civil_complaint_manual_medium'}, page_content='- ~~팀장~~ 민원인 진정 및 경고 → (폭언 등 지속시) 퇴거 조치 → 안전요원(경찰)과 동행\n※ 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의\n- ~~팀원~~ 담당자 분리 조치, 녹화(음) 실시, 타 민원인 대피, 안전요원 호출, 퇴거\n불응시 경찰 신고 등\n‣ ~~부서장은 피해직원 면담 및 충분한 휴식 조치~~\n면담 후 60분 이내 휴게시간 부여(필요시 추가 부여)\n담당자(팀장)는 위법행위 관리대장(특이민원 발생보고서) 작성\n‣ ~~부서장이 전담부서와 협의하여 법적 조치 등 필요사항 조치~~\n녹음파일 청취 및 상황파악, 특이민원 발생보고서 검토\n※ 필요시, 서면 경고문 발송(우편, SMS)\n고소, 고발 등 법적 조치사항 등에 대해 법적대응 전담부서 협의\n- ~~팀원~~ 담당자 분리조치, 녹화(음) 실시, 안전요원 호출 및 경찰 신고 등\n‣ ~~폭행 발생 시 비상대응팀 업무분장에 따라 신속히 행동~~\n비상대응팀 직원별 역할 수행\n- ~~팀장~~ 민원인 제지 및 경고, 안전요원(경찰)과 동행\n~~경고~~ 선생님, 공무원에 대한 폭행은 형법 제136조 공무집행방해죄에\n해당되어 처벌받을 수 있습니다. 경찰에 신고하겠습니다.\n※ 경찰 도착 전까지 민원인 진정 및 착석을 유도하는 등 추가 피해 방지')],
#  'context': '[근거 1] page=8, chunk=11\n3-1 폭언(욕설, 협박, 성희롱 등)\n3-2 폭행\n‣ ~~폭행 발생 징후가 보일 경우 즉시 주변에 도움 요청,~~\n~~담당자 현장에서 분리조치, 팀장 등 경고멘트 발언 및 개입~~\n녹화(음) 중이 아닐 경우 즉시 녹화(음) 실시\n선생님, 위협적인 행동과 말씀으로 더 이상 정상적인 상담이 어렵습니다.\n팀장님(주무관님) 도움 부탁드립니다.\n비상대응팀 업무분장에 따라 신속히 대응\n- ~~팀장~~ 민원인 진정 및 경고 → 퇴거 조치 → 안전요원(경찰)과 동행\n※ 진정되지 않고 폭행 발생이 예상되는 경우 즉시 경찰 신고\n‣ ~~상담곤란 안내 후 상담 종료, 주변 도움 요청~~\n녹화(음) 중이 아닐 경우 즉시 녹화(음) 실시\n선생님, 폭언을 하시면 정상적인 상담이 어렵습니다. 폭언을 중단해 주십시오.\n계속 폭언을 하시면 관련 법령에 따라 처벌받을 수 있습니다.\n팀장님(주무관님) 민원인이 폭언을 하셔서 더 이상 상담이 어려우니 도움\n부탁드립니다.\n‣ ~~비상대응팀 업무분장에 따라 신속히 행동~~\n비상대응팀 직원별 역할 수행\n- ~~팀장~~ 민원인 진정 및 경고 → (폭언 등 지속시) 퇴거 조치 → 안전요원(경찰)과 동행\n※ 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의\n\n[근거 2] page=10, chunk=17\n4-1 폭언(욕설, 협박, 성희롱 등)\n핵심대응 전화·대면 폭언 등에 준하여 대응함으로써 민원인에게 경각심 부여\n4-2 정당한 사유없는 반복민원 ※ 민원처리법 제23조, 제34조\n핵심대응 반복민원 종결처리로 불필요한 행정력 낭비 방지\n‣ ~~처리 주무부서장 결재로 종결~~\n※ 2차 답변시 민원인의 이해를 높이는 방식으로 대응, 기존 답변 단순복사,\n동문서답 등 성의없는 답변 후 종결 처리로 국민불만 발생 유의\n[종결처리 통지] 최초 종결 처리시, 민원인에게 종결처리 사실을 통지\n하고 이후 제기된 반복민원은 처리결과 회신없이 종결\n[처리기준] 동일한 내용의 민원을 3회이상 반복 제출한 경우 2회이상\n그 결과를 통지하고 이후 접수 민원은 종결처리 가능\n‣ ~~기관별 민원조정위원회 심의~~\n종결 처리 후 다시 접수된 반복민원 중 처리주무부서장이 신중한\n처리가 필요하다고 판단, 기관별 민원조정위원회 심의로 종결\n‣ ~~해당 민원 내용을 부서장에게 보고~~\n담당자는 위법행위 관리대장 작성, 부서장 보고\n※ 필요시 특이민원 발생보고서 작성(상황에 따라 구두보고 후 작성)\n‣ ~~경고공문 통지~~\n민원 회신 시 법적조치 등을 취할 수 있다는 경고문구 포함 회신\n[ 경고문구(예시) ]\n◦ 귀하께서 2000.00.00. 에 제출하신 민원(제목:00) 내용 중 “×××”는 「00법」 제0조\n\n[근거 3] page=4, chunk=4\nSTEP\nSTEP\n- 정중한 억양 및 어투를 사용하며, 민원사항에 대한 공감·경청\n※무성의한 응대나 주관적·모호한 응대 주의\n- 민원인 문의사항을 집중하여 끝까지 듣고, 필요시 확인을 통해\n민원사항을 정확히 파악\nSTEP\n- 민원인의 눈높이에 맞춘 정확하고 이해하기 쉬운 설명 진행\nSTEP\nSTEP\n- 민원인이 제기한 불만 원인을 파악하고, 절차 안내, 민원 해결 방안\n또는 민원인에게 해결이 어려운 상황을 설명\n※ 명확한 근거규정을 제시하고 어려울 경우 충분한 준비 후 재응대\n- 민원인에게 민원문서의 보완 요구, 처리진행상황 및 처리결과를\n통보할 때에는 담당자의 소속·성명 및 연락처를 안내\nSTEP\nSTEP\n- 민원인의 방문목적을 확인하고 민원처리 또는 상담을 진행\n※ 상담 중 민원인과의 마찰 또는 갈등이 발생할 우려가 있는 경우에는 부서장 또는\n상급자가 적극 개입하여 민원인을 진정시키고 갈등을 해소할 수 있도록 노력\n- 민원인의 질문과 요구를 적극적으로 해결하기 위해 노력\n※ 자신의 업무 범위만 내세워 소극적으로 대처하지 않음\nSTEP\n- 처리에 시간이 걸리는 민원은 소요시간과 절차 안내\nII. 일반적인 민원 응대요령 | **11**\n\n[근거 4] page=8, chunk=12\n- ~~팀장~~ 민원인 진정 및 경고 → (폭언 등 지속시) 퇴거 조치 → 안전요원(경찰)과 동행\n※ 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의\n- ~~팀원~~ 담당자 분리 조치, 녹화(음) 실시, 타 민원인 대피, 안전요원 호출, 퇴거\n불응시 경찰 신고 등\n‣ ~~부서장은 피해직원 면담 및 충분한 휴식 조치~~\n면담 후 60분 이내 휴게시간 부여(필요시 추가 부여)\n담당자(팀장)는 위법행위 관리대장(특이민원 발생보고서) 작성\n‣ ~~부서장이 전담부서와 협의하여 법적 조치 등 필요사항 조치~~\n녹음파일 청취 및 상황파악, 특이민원 발생보고서 검토\n※ 필요시, 서면 경고문 발송(우편, SMS)\n고소, 고발 등 법적 조치사항 등에 대해 법적대응 전담부서 협의\n- ~~팀원~~ 담당자 분리조치, 녹화(음) 실시, 안전요원 호출 및 경찰 신고 등\n‣ ~~폭행 발생 시 비상대응팀 업무분장에 따라 신속히 행동~~\n비상대응팀 직원별 역할 수행\n- ~~팀장~~ 민원인 제지 및 경고, 안전요원(경찰)과 동행\n~~경고~~ 선생님, 공무원에 대한 폭행은 형법 제136조 공무집행방해죄에\n해당되어 처벌받을 수 있습니다. 경찰에 신고하겠습니다.\n※ 경찰 도착 전까지 민원인 진정 및 착석을 유도하는 등 추가 피해 방지',
#  'evidence': '1. 폭행 발생 징후가 보일 경우 즉시 주변에 도움 요청, 담당자 현장에서 분리조치, 팀장 등 경고멘트 발언 및 개입 (page=8, chunk=11).\n2. 폭행 발생 시 즉시 경찰 신고 (page=8, chunk=11).\n3. 민원인 진정 및 경고 후 퇴거 조치, 안전요원(경찰)과 동행 (page=8, chunk=12).\n4. 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의 (page=8, chunk=12).\n5. 담당자는 위법행위 관리대장 작성 및 부서장에게 보고 (page=8, chunk=12).\n6. 비상대응팀 업무분장에 따라 신속히 행동 (page=8, chunk=12).\n7. 공무원에 대한 폭행은 형법 제136조 공무집행방해죄에 해당되어 처벌받을 수 있음 (page=8, chunk=12).',
#  'answer': '1. 핵심 대응\n   - 폭행 발생 시 즉시 경찰에 신고하고, 민원인을 진정 및 퇴거 조치합니다.\n\n2. 단계별 조치\n   1. 폭행 발생 징후가 보일 경우 즉시 주변에 도움 요청.\n   2. 담당자를 현장에서 분리조치하고, 팀장 등에게 경고멘트를 발언 및 개입 요청.\n   3. 폭행이 발생하면 즉시 경찰에 신고.\n   4. 민원인을 진정시키고 경고 후 퇴거 조치.\n   5. 안전요원(경찰)과 동행하여 민원인을 퇴거.\n   6. 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의.\n   7. 담당자는 위법행위 관리대장을 작성하고 부서장에게 보고.\n   8. 비상대응팀 업무분장에 따라 신속히 행동.\n\n3. 사용할 수 있는 안내 표현\n   - "주변에 도움을 요청하겠습니다."\n   - "경찰에 신고하겠습니다."\n   - "퇴거 조치를 취하겠습니다. 신체접촉은 하지 않겠습니다."\n\n4. 담당자 보호조치\n   - 폭행 발생 시 즉시 현장에서 분리조치하고, 경찰 신고 후 안전요원과 동행하여 민원인을 퇴거시킵니다.\n\n5. 주의사항\n   - 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의해야 합니다.\n   - 공무원에 대한 폭행은 형법 제136조에 따라 처벌받을 수 있음을 인지해야 합니다.\n\n6. 문서 페이지\n   - 페이지 8, 청크 11 및 12.',
#  'validation': '충분\n\n답변은 폭행 발생 시 취해야 할 조치에 대해 명확하고 구체적으로 설명하고 있으며, 제공된 근거에 잘 기반하고 있습니다. 각 단계별 조치와 주의사항이 잘 정리되어 있어 실질적인 대응 방안을 제시하고 있습니다. 또한, 법적 근거에 대한 언급도 포함되어 있어 폭행의 심각성을 강조하고 있습니다.'}

# %%
question = "대면 민원 중 폭행이 발생하면 어떻게 해야 하나요?"

result = app.invoke({
    "question": question
})

# result
print("[질문 유형]")
print(result["case_type"])

print("\n[검색 질의]")
print(result["rewritten_query"])

print("\n[근거 정리]")
print(result["evidence"])

print("\n[답변]")
print(result["answer"])

print("\n[검증]")
print(result["validation"])
# Out:
# [질문 유형]
# face_to_face_abuse
#
# [검색 질의]
# 대면 민원 중 폭행이 발생하면 어떻게 해야 하나요?
# 검색 키워드: 대면응대 폭언 욕설 협박 성희롱 녹화 녹음 상담 종료
#
# [근거 정리]
# 1. 폭행 발생 징후가 보일 경우 즉시 주변에 도움 요청, 담당자 현장에서 분리조치, 팀장 등 경고멘트 발언 및 개입 (page=8, chunk=11).
# 2. 폭행 발생 시 즉시 경찰 신고 (page=8, chunk=11).
# 3. 민원인 진정 및 경고 후 퇴거 조치, 안전요원(경찰)과 동행 (page=8, chunk=12).
# 4. 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의 (page=8, chunk=12).
# 5. 비상대응팀 업무분장에 따라 신속히 행동 (page=8, chunk=12).
# 6. 폭행 시 경찰에 신고하겠다는 경고 (page=8, chunk=12).
#
# [답변]
# 1. 핵심 대응
#    - 폭행 발생 시 즉시 경찰에 신고하고, 민원인을 진정시키며 퇴거 조치를 취합니다.
#
# 2. 단계별 조치
#    1. 폭행 발생 징후가 보일 경우 즉시 주변에 도움 요청.
#    2. 담당자를 현장에서 분리 조치하고, 팀장 등에게 경고멘트를 발언 및 개입 요청.
#    3. 폭행이 발생하면 즉시 경찰에 신고.
#    4. 민원인을 진정시키고 경고 후 퇴거 조치.
#    5. 안전요원(경찰)과 동행하여 민원인을 퇴거.
#    6. 퇴거 조치는 멘트로만 통보하고 신체접촉이 발생하지 않도록 유의.
#    7. 비상대응팀 업무분장에 따라 신속히 행동.
#
# 3. 사용할 수 있는 안내 표현
#    - "이곳은 공공기관으로, 폭행이 발생할 경우 경찰에 신고하겠습니다."
#    - "안전한 환경을 위해 퇴거 조치를 취하겠습니다."
#
# 4. 담당자 보호조치
#    - 담당자는 민원인과의 신체적 접촉을 피하고, 안전한 거리에서 대처합니다.
#
# 5. 주의사항
#    - 폭행 발생 시 즉시 대응하되, 상황을 악화시키지 않도록 유의합니다.
#    - 퇴거 조치는 신체접촉 없이 멘트로만 통보해야 합니다.
#
# 6. 문서 페이지
#    - 페이지 8, 청크 11 및 12.
#
# [검증]
# 충분
#
# 답변은 폭행 발생 시 취해야 할 조치에 대해 명확하고 구체적으로 설명하고 있습니다. 근거 1과 근거 4에서 제시된 내용을 바탕으로, 폭행 징후가 보일 경우의 대응, 경찰 신고, 민원인 진정 및 퇴거 조치, 안전요원과의 동행 등 필요한 절차를 잘 정리하였습니다. 또한, 사용 가능한 안내 표현과 담당자의 보호 조치에 대한 언급도 포함되어 있어 실질적인 대응 방안을 제시하고 있습니다. 전반적으로 근거에 기반하여 충분한 정보를 제공하고 있습니다.

# %% [markdown]
# ## 핵심 정리
#
# ```text
# START
# → classify_question
# → retrieve_manual
# → organize_evidence
# → generate_answer
# → validate_answer
# → END
# ```
#
# - Modular RAG는 기능을 모듈로 분리한다.
# - 질문 분류, 검색, 근거 정리, 답변 생성, 검증을 각각 독립 노드로 구성한다.
